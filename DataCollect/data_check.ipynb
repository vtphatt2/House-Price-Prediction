# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Data/crawl_data.csv")
df
# Out:
#     No       Price   Area  Bedrooms   WCs  \
# 0    1  3899000000  150.0       2.0   1.0
# 1    2         5.5   51.0       NaN   NaN
# 2    3         4.6   45.0       2.0   2.0
# 3    4        7.35   41.0       NaN   NaN
# 4    5          TT   96.0       2.0   1.0
# 5    6        3.95   40.0       4.0   3.0
# 6    7        3.95   40.0       4.0   3.0
# 7    8        7.95   59.0       NaN   NaN
# 8    9          TT    NaN       3.0   3.0
# 9   10          17  425.0       6.0   6.0
# 10  11          19  180.0       NaN   NaN
# 11  12        5.29   42.0       4.0   3.0
# 12  13         8.6   39.0       4.0   5.0
# 13  14        21.8   80.0       8.0   8.0
# 14  15        5.95   40.0       3.0   4.0
# 15  16           4   33.0       3.0   3.0
# 16  17         6.9   54.0       NaN   NaN
# 17  18          19  118.0       NaN   NaN
# 18  19          TT    NaN       NaN   NaN
# 19  20         1.6  110.0       3.0   2.0
# 20  21         1.6  110.0       3.0   2.0
# ...
