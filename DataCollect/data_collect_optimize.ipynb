# %%
import requests
# Out:
# /Users/VoThinhPhat/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def get_html_source_as_string(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for non-2xx status codes
        return response.text
    except requests.exceptions.RequestException as e:
        print(f"An error occurred fetching the URL: {e}")
        return None

# %%
def get_sublinks(url) :  
    html_source = get_html_source_as_string(url)
    sublinks = []

    substring = "<div class=\"image cover\">\n												<a href=\""
    len_sub_string = len(substring)

    for i in range(len(html_source)) :
        if (html_source[i] == "<" and html_source[i + 1] == "d") :
            match = True
            j = 0
            while (j < len_sub_string) :
                if (html_source[i + j] != substring[j]) :
                    match = False
                    break
                j += 1
            if (match) :
                sublink = ""
                while (html_source[i + j] != "\"") :
                    sublink += html_source[i + j]
                    i += 1
                sublinks.append(sublink)
                i = i + j + 1
    return sublinks

# %%
def remove_all_substring(string, substring):
    new_string = ""
    i = 0
    while i < len(string):
        if string[i:].startswith(substring):
            i += len(substring)
        else:
            new_string += string[i]
            i += 1
    return new_string

# %%
substring1 = "<h1 class=\"uk-panel-title\"><span>"
len_sub_string1 = len(substring1)

substring2 = "<strong class=\"price\">\n"
len_sub_string2 = len(substring2)

substring3 = "Diện tích:</strong>"
len_sub_string3 = len(substring3)

substring4 = "Phòng ngủ:</strong>"
len_sub_string4 = len(substring4)

substring5 = "Phòng WC:</strong>"
len_sub_string5 = len(substring5)

substring6 = "Địa chỉ:</strong> "
len_sub_string6 = len(substring6)

substring7 = "Ngày đăng:</strong>"
len_sub_string7 = len(substring7)

substring8 = "Nội dung tin đăng</span>"
len_sub_string8 = len(substring8)

def get_data_to_csv(url, file_path, no, district) :
    html_source = get_html_source_as_string(url)

    title = ""
    price = ""
    area = ""
    bedrooms = ""
    WCs = ""
    # address = ""
    postdate = ""
    description = ""

    for i in range(len(html_source)) :
        # get title
        if (html_source[i] == "<" and html_source[i + 1] == "h" and html_source[i + 2] == "1") :
            match = True
            j = 0
            while (j < len_sub_string1) :
                if (html_source[i + j] != substring1[j]) :
                    match = False
                    break
                j += 1
            if (match) :
                while (html_source[i + j] != "<") :
                    title += html_source[i + j]
                    i += 1
                i = i + j + 1
                
        # get price
        if (html_source[i] == "<" and html_source[i + 1] == "s" and html_source[i + 2] == "t") :
            match = True
            j = 0
            while (j < len_sub_string2) :
                if (html_source[i + j] != substring2[j]) :
                    match = False
                    break
                j += 1
            if (match) :
                while ((html_source[i + j] < '0' or html_source[i + j] > '9') and html_source[i + j] != '<') :
                    i += 1
                if (html_source[i + j] != '<') :
                    while (html_source[i + j] != " ") :
                        price += html_source[i + j]
                        i += 1
                if (price == "") :
                    price = "TT"
                i = i + j + 1 

        # get area
        if (html_source[i] == "D" and html_source[i + 1] == "i" and html_source[i + 2] == "ệ") :
            match = True
            j = 0
            while (j < len_sub_string3) :
                if (html_source[i + j] != substring3[j]) :
                    match = False
                    break
                j += 1
            if (match) :
                while (html_source[i + j] < '0' or html_source[i + j] > '9') :
                    i += 1
                while (html_source[i + j] != " ") :
                    area += html_source[i + j]
                    i += 1
                i = i + j + 1 

        # get bedrooms
        if (html_source[i] == "P" and html_source[i + 1] == "h" and html_source[i + 2] == "ò"
            and html_source[i + 6] == "n") :
            match = True
            j = 0
            while (j < len_sub_string4) :
                if (html_source[i + j] != substring4[j]) :
                    match = False
                    break
                j += 1
            if (match) :
                while (html_source[i + j] < '0' or html_source[i + j] > '9') :
                    i += 1
                while (html_source[i + j] != " ") :
                    bedrooms += html_source[i + j]
                    i += 1
                i = i + j + 1 
        
        # get WCs
        if (html_source[i] == "P" and html_source[i + 1] == "h" and html_source[i + 2] == "ò"
            and html_source[i + 6] == "W") :
            match = True
            j = 0
            while (j < len_sub_string5) :
                if (html_source[i + j] != substring5[j]) :
                    match = False
                    break
                j += 1
            if (match) :
                while (html_source[i + j] < '0' or html_source[i + j] > '9') :
                    i += 1
                while (html_source[i + j] != " ") :
                    WCs += html_source[i + j]
                    i += 1
                i = i + j + 1 
            
        # # get address
        # if (html_source[i] == "Đ" and html_source[i + 1] == "ị" and html_source[i + 2] == "a") :
        #     match = True
        #     j = 0
        #     while (j < len_sub_string6) :
        #         if (html_source[i + j] != substring6[j]) :
        #             match = False
        #             break
        #         j += 1
        #     if (match) :
        #         while (html_source[i + j] != "<") :
        #             address += html_source[i + j]
        #             i += 1
        #         i = i + j + 1      

        # get postdate
        if (html_source[i] == "N" and html_source[i + 1] == "g" and html_source[i + 2] == "à") :
            match = True
            j = 0
            while (j < len_sub_string7) :
                if (html_source[i + j] != substring7[j]) :
                    match = False
                    break
                j += 1
            if (match) :
                while (html_source[i + j] < '0' or html_source[i + j] > '9') :
                    i += 1
                while (html_source[i + j] != "\"") :
                    postdate += html_source[i + j]
                    i += 1
                i = i + j + 1   

        # get description    
        if (html_source[i] == "N" and html_source[i + 1] == "ộ" and html_source[i + 2] == "i") :
            match = True
            j = 0
            while (j < len_sub_string8) :
                if (html_source[i + j] != substring8[j]) :
                    match = False
                    break
                j += 1
            if (match) :
                while (i + j + 4 < len(html_source) and (html_source[i + j] != '<' or html_source[i + j + 1] != 'b'
                       or html_source[i + j + 2] != 'r' or html_source[i + j + 3] != ' '
                       or html_source[i + j + 4] != '/')):
                    i += 1
                i = i + 8
                while (i + j + 3 < len(html_source) and (html_source[i + j] != '<' or html_source[i + j + 1] != '/'
                       or html_source[i + j + 2] != 'p' or html_source[i + j + 3] != '>')) :
                    description += html_source[i + j]
                    i += 1
                i = i + j + 1          

                description = remove_all_substring(description, "<br />")
                description = description.replace('\n', '|')
                description = description.replace('\r', ' ')

    with open(file_path, 'a') as f :
        f.write(str(no) + "," + price + ",\"" + title + "\"," + area + "," + bedrooms + ","
            + WCs + ",\"" + district + "\"," + postdate + ",\"" + description + "\"\n")
        
    # with open(file_path, 'a') as f :
    #     f.write(str(no) + ",\"" + title + "\"," + price + "," + area + "," + bedrooms + ","
    #         + WCs + ",\"" + address + "\"," + postdate + "\n")

# %%
# number of pages that you want to scrape
pages = 200

# %%
data_size = 0
districts = ['quan-1', 'quan-2', 'quan-3', 'quan-4', 'quan-5',
            'quan-6', 'quan-7', 'quan-8', 'quan-9', 'quan-10',
            'quan-11', 'quan-12', 'binh-chanh', 'binh-tan', 'binh-thanh',
            'can-gio', 'cu-chi', 'go-vap', 'hoc-mon', 'nha-be', 
            'phu-nhuan', 'tan-binh', 'tan-phu', 'thu-duc']


filepath = "../Data/crawl_data.csv"
with open(filepath, 'w') as f:
    f.write("No,Price,Title,Area,Bedrooms,WCs,District,Postdate,Description\n")
    
for district in districts :
    i = 0
    while (True) : 
        i += 1
        sublinks = get_sublinks("https://batdongsan.vn/ban-nha-" + district + "-ho-chi-minh/p" + str(i))
        if len(sublinks) == 0 :
            break
        for j in range(len(sublinks)) :
            data_size += 1
            get_data_to_csv(sublinks[j], filepath, data_size, district)
            print(f"Record {data_size} is done...")

print("Get dataset done !")
# Out:
# Record 1 is done...
# Record 2 is done...
# Record 3 is done...
# Record 4 is done...
# Record 5 is done...
# Record 6 is done...
# Record 7 is done...
# Record 8 is done...
# Record 9 is done...
# Record 10 is done...
# Record 11 is done...
# Record 12 is done...
# Record 13 is done...
# Record 14 is done...
# Record 15 is done...
# Record 16 is done...
# Record 17 is done...
# Record 18 is done...
# Record 19 is done...
# Record 20 is done...
# Record 21 is done...
# Record 22 is done...
# Record 23 is done...
# Record 24 is done...
# Record 25 is done...
# Record 26 is done...
# Record 27 is done...
# Record 28 is done...
# Record 29 is done...
# Record 30 is done...
# Record 31 is done...
# Record 32 is done...
# Record 33 is done...
# Record 34 is done...
# Record 35 is done...
# Record 36 is done...
# Record 37 is done...
# Record 38 is done...
# Record 39 is done...
# Record 40 is done...
# Record 41 is done...
# Record 42 is done...
# Record 43 is done...
# Record 44 is done...
# Record 45 is done...
# Record 46 is done...
# Record 47 is done...
# Record 48 is done...
# Record 49 is done...
# Record 50 is done...
# Record 51 is done...
# Record 52 is done...
# Record 53 is done...
# Record 54 is done...
# Record 55 is done...
# Record 56 is done...
# Record 57 is done...
# Record 58 is done...
# Record 59 is done...
# Record 60 is done...
# Record 61 is done...
# Record 62 is done...
# Record 63 is done...
# Record 64 is done...
# Record 65 is done...
# Record 66 is done...
# Record 67 is done...
# Record 68 is done...
# Record 69 is done...
# Record 70 is done...
# Record 71 is done...
# Record 72 is done...
# Record 73 is done...
# Record 74 is done...
# Record 75 is done...
# Record 76 is done...
# Record 77 is done...
# Record 78 is done...
# Record 79 is done...
# Record 80 is done...
# Record 81 is done...
# Record 82 is done...
# Record 83 is done...
# Record 84 is done...
# Record 85 is done...
# Record 86 is done...
# Record 87 is done...
# Record 88 is done...
# Record 89 is done...
# Record 90 is done...
# Record 91 is done...
# Record 92 is done...
# Record 93 is done...
# Record 94 is done...
# Record 95 is done...
# Record 96 is done...
# Record 97 is done...
# Record 98 is done...
# Record 99 is done...
# Record 100 is done...
# Record 101 is done...
# Record 102 is done...
# Record 103 is done...
# Record 104 is done...
# Record 105 is done...
# Record 106 is done...
# Record 107 is done...
# Record 108 is done...
# Record 109 is done...
# Record 110 is done...
# Record 111 is done...
# Record 112 is done...
# Record 113 is done...
# Record 114 is done...
# Record 115 is done...
# Record 116 is done...
# Record 117 is done...
# Record 118 is done...
# Record 119 is done...
# Record 120 is done...
# Record 121 is done...
# Record 122 is done...
# Record 123 is done...
# Record 124 is done...
# Record 125 is done...
# Record 126 is done...
# Record 127 is done...
# Record 128 is done...
# Record 129 is done...
# Record 130 is done...
# Record 131 is done...
# Record 132 is done...
# Record 133 is done...
# Record 134 is done...
# Record 135 is done...
# Record 136 is done...
# Record 137 is done...
# Record 138 is done...
# Record 139 is done...
# Record 140 is done...
# Record 141 is done...
# Record 142 is done...
# Record 143 is done...
# Record 144 is done...
# Record 145 is done...
# Record 146 is done...
# Record 147 is done...
# Record 148 is done...
# Record 149 is done...
# Record 150 is done...
# Record 151 is done...
# Record 152 is done...
# Record 153 is done...
# Record 154 is done...
# Record 155 is done...
# Record 156 is done...
# Record 157 is done...
# Record 158 is done...
# Record 159 is done...
# Record 160 is done...
# Record 161 is done...
# Record 162 is done...
# Record 163 is done...
# Record 164 is done...
# Record 165 is done...
# Record 166 is done...
# Record 167 is done...
# Record 168 is done...
# Record 169 is done...
# Record 170 is done...
# Record 171 is done...
# Record 172 is done...
# Record 173 is done...
# Record 174 is done...
# Record 175 is done...
# Record 176 is done...
# Record 177 is done...
# Record 178 is done...
# Record 179 is done...
# Record 180 is done...
# Record 181 is done...
# Record 182 is done...
# Record 183 is done...
# Record 184 is done...
# Record 185 is done...
# Record 186 is done...
# Record 187 is done...
# Record 188 is done...
# Record 189 is done...
# Record 190 is done...
# Record 191 is done...
# Record 192 is done...
# Record 193 is done...
# Record 194 is done...
# Record 195 is done...
# Record 196 is done...
# Record 197 is done...
# Record 198 is done...
# Record 199 is done...
# Record 200 is done...
# Record 201 is done...
# Record 202 is done...
# Record 203 is done...
# Record 204 is done...
# Record 205 is done...
# Record 206 is done...
# Record 207 is done...
# Record 208 is done...
# Record 209 is done...
# Record 210 is done...
# Record 211 is done...
# Record 212 is done...
# Record 213 is done...
# Record 214 is done...
# Record 215 is done...
# Record 216 is done...
# Record 217 is done...
# Record 218 is done...
# Record 219 is done...
# Record 220 is done...
# Record 221 is done...
# Record 222 is done...
# Record 223 is done...
# Record 224 is done...
# Record 225 is done...
# Record 226 is done...
# Record 227 is done...
# Record 228 is done...
# Record 229 is done...
# Record 230 is done...
# Record 231 is done...
# Record 232 is done...
# Record 233 is done...
# Record 234 is done...
# Record 235 is done...
# Record 236 is done...
# Record 237 is done...
# Record 238 is done...
# Record 239 is done...
# Record 240 is done...
# Record 241 is done...
# Record 242 is done...
# Record 243 is done...
# Record 244 is done...
# Record 245 is done...
# Record 246 is done...
# Record 247 is done...
# Record 248 is done...
# Record 249 is done...
# Record 250 is done...
# Record 251 is done...
# Record 252 is done...
# Record 253 is done...
# Record 254 is done...
# Record 255 is done...
# Record 256 is done...
# Record 257 is done...
# Record 258 is done...
# Record 259 is done...
# Record 260 is done...
# Record 261 is done...
# Record 262 is done...
# Record 263 is done...
# Record 264 is done...
# Record 265 is done...
# Record 266 is done...
# Record 267 is done...
# Record 268 is done...
# Record 269 is done...
# Record 270 is done...
# Record 271 is done...
# Record 272 is done...
# Record 273 is done...
# Record 274 is done...
# Record 275 is done...
# Record 276 is done...
# Record 277 is done...
# Record 278 is done...
# Record 279 is done...
# Record 280 is done...
# Record 281 is done...
# Record 282 is done...
# Record 283 is done...
# Record 284 is done...
# Record 285 is done...
# Record 286 is done...
# Record 287 is done...
# Record 288 is done...
# Record 289 is done...
# Record 290 is done...
# Record 291 is done...
# Record 292 is done...
# Record 293 is done...
# Record 294 is done...
# Record 295 is done...
# Record 296 is done...
# Record 297 is done...
# Record 298 is done...
# Record 299 is done...
# Record 300 is done...
# Record 301 is done...
# Record 302 is done...
# Record 303 is done...
# Record 304 is done...
# Record 305 is done...
# Record 306 is done...
# Record 307 is done...
# Record 308 is done...
# Record 309 is done...
# Record 310 is done...
# Record 311 is done...
# Record 312 is done...
# Record 313 is done...
# Record 314 is done...
# Record 315 is done...
# Record 316 is done...
# Record 317 is done...
# Record 318 is done...
# Record 319 is done...
# Record 320 is done...
# Record 321 is done...
# Record 322 is done...
# Record 323 is done...
# Record 324 is done...
# Record 325 is done...
# Record 326 is done...
# Record 327 is done...
# Record 328 is done...
# Record 329 is done...
# Record 330 is done...
# Record 331 is done...
# Record 332 is done...
# Record 333 is done...
# Record 334 is done...
# Record 335 is done...
# Record 336 is done...
# Record 337 is done...
# Record 338 is done...
# Record 339 is done...
# Record 340 is done...
# Record 341 is done...
# Record 342 is done...
# Record 343 is done...
# Record 344 is done...
# Record 345 is done...
# Record 346 is done...
# Record 347 is done...
# Record 348 is done...
# Record 349 is done...
# Record 350 is done...
# Record 351 is done...
# Record 352 is done...
# Record 353 is done...
# Record 354 is done...
# Record 355 is done...
# Record 356 is done...
# Record 357 is done...
# Record 358 is done...
# Record 359 is done...
# Record 360 is done...
# Record 361 is done...
# Record 362 is done...
# Record 363 is done...
# Record 364 is done...
# Record 365 is done...
# Record 366 is done...
# Record 367 is done...
# Record 368 is done...
# Record 369 is done...
# Record 370 is done...
# Record 371 is done...
# Record 372 is done...
# Record 373 is done...
# Record 374 is done...
# Record 375 is done...
# Record 376 is done...
# Record 377 is done...
# Record 378 is done...
# Record 379 is done...
# Record 380 is done...
# Record 381 is done...
# Record 382 is done...
# Record 383 is done...
# Record 384 is done...
# Record 385 is done...
# Record 386 is done...
# Record 387 is done...
# Record 388 is done...
# Record 389 is done...
# Record 390 is done...
# Record 391 is done...
# Record 392 is done...
# Record 393 is done...
# Record 394 is done...
# Record 395 is done...
# Record 396 is done...
# Record 397 is done...
# Record 398 is done...
# Record 399 is done...
# Record 400 is done...
# Record 401 is done...
# Record 402 is done...
# Record 403 is done...
# Record 404 is done...
# Record 405 is done...
# Record 406 is done...
# Record 407 is done...
# Record 408 is done...
# Record 409 is done...
# Record 410 is done...
# Record 411 is done...
# Record 412 is done...
# Record 413 is done...
# Record 414 is done...
# Record 415 is done...
# Record 416 is done...
# Record 417 is done...
# Record 418 is done...
# Record 419 is done...
# Record 420 is done...
# Record 421 is done...
# Record 422 is done...
# Record 423 is done...
# Record 424 is done...
# Record 425 is done...
# Record 426 is done...
# Record 427 is done...
# Record 428 is done...
# Record 429 is done...
# Record 430 is done...
# Record 431 is done...
# Record 432 is done...
# Record 433 is done...
# Record 434 is done...
# Record 435 is done...
# Record 436 is done...
# Record 437 is done...
# Record 438 is done...
# Record 439 is done...
# Record 440 is done...
# Record 441 is done...
# Record 442 is done...
# Record 443 is done...
# Record 444 is done...
# Record 445 is done...
# Record 446 is done...
# Record 447 is done...
# Record 448 is done...
# Record 449 is done...
# Record 450 is done...
# Record 451 is done...
# Record 452 is done...
# Record 453 is done...
# Record 454 is done...
# Record 455 is done...
# Record 456 is done...
# Record 457 is done...
# Record 458 is done...
# Record 459 is done...
# Record 460 is done...
# Record 461 is done...
# Record 462 is done...
# Record 463 is done...
# Record 464 is done...
# Record 465 is done...
# Record 466 is done...
# Record 467 is done...
# Record 468 is done...
# Record 469 is done...
# Record 470 is done...
# Record 471 is done...
# Record 472 is done...
# Record 473 is done...
# Record 474 is done...
# Record 475 is done...
# Record 476 is done...
# Record 477 is done...
# Record 478 is done...
# Record 479 is done...
# Record 480 is done...
# Record 481 is done...
# Record 482 is done...
# Record 483 is done...
# Record 484 is done...
# Record 485 is done...
# Record 486 is done...
# Record 487 is done...
# Record 488 is done...
# Record 489 is done...
# Record 490 is done...
# Record 491 is done...
# Record 492 is done...
# Record 493 is done...
# Record 494 is done...
# Record 495 is done...
# Record 496 is done...
# Record 497 is done...
# Record 498 is done...
# Record 499 is done...
# Record 500 is done...
# Record 501 is done...
# Record 502 is done...
# Record 503 is done...
# Record 504 is done...
# Record 505 is done...
# Record 506 is done...
# Record 507 is done...
# Record 508 is done...
# Record 509 is done...
# Record 510 is done...
# Record 511 is done...
# Record 512 is done...
# Record 513 is done...
# Record 514 is done...
# Record 515 is done...
# Record 516 is done...
# Record 517 is done...
# Record 518 is done...
# Record 519 is done...
# Record 520 is done...
# Record 521 is done...
# Record 522 is done...
# Record 523 is done...
# Record 524 is done...
# Record 525 is done...
# Record 526 is done...
# Record 527 is done...
# Record 528 is done...
# Record 529 is done...
# Record 530 is done...
# Record 531 is done...
# Record 532 is done...
# Record 533 is done...
# Record 534 is done...
# Record 535 is done...
# Record 536 is done...
# Record 537 is done...
# Record 538 is done...
# Record 539 is done...
# Record 540 is done...
# Record 541 is done...
# Record 542 is done...
# Record 543 is done...
# Record 544 is done...
# Record 545 is done...
# Record 546 is done...
# Record 547 is done...
# Record 548 is done...
# Record 549 is done...
# Record 550 is done...
# Record 551 is done...
# Record 552 is done...
# Record 553 is done...
# Record 554 is done...
# Record 555 is done...
# Record 556 is done...
# Record 557 is done...
# Record 558 is done...
# Record 559 is done...
# Record 560 is done...
# Record 561 is done...
# Record 562 is done...
# Record 563 is done...
# Record 564 is done...
# Record 565 is done...
# Record 566 is done...
# Record 567 is done...
# Record 568 is done...
# Record 569 is done...
# Record 570 is done...
# Record 571 is done...
# Record 572 is done...
# Record 573 is done...
# Record 574 is done...
# Record 575 is done...
# Record 576 is done...
# Record 577 is done...
# Record 578 is done...
# Record 579 is done...
# Record 580 is done...
# Record 581 is done...
# Record 582 is done...
# Record 583 is done...
# Record 584 is done...
# Record 585 is done...
# Record 586 is done...
# Record 587 is done...
# Record 588 is done...
# Record 589 is done...
# Record 590 is done...
# Record 591 is done...
# Record 592 is done...
# Record 593 is done...
# Record 594 is done...
# Record 595 is done...
# Record 596 is done...
# Record 597 is done...
# Record 598 is done...
# Record 599 is done...
# Record 600 is done...
# Record 601 is done...
# Record 602 is done...
# Record 603 is done...
# Record 604 is done...
# Record 605 is done...
# Record 606 is done...
# Record 607 is done...
# Record 608 is done...
# Record 609 is done...
# Record 610 is done...
# Record 611 is done...
# Record 612 is done...
# Record 613 is done...
# Record 614 is done...
# Record 615 is done...
# Record 616 is done...
# Record 617 is done...
# Record 618 is done...
# Record 619 is done...
# Record 620 is done...
# Record 621 is done...
# Record 622 is done...
# Record 623 is done...
# Record 624 is done...
# Record 625 is done...
# Record 626 is done...
# Record 627 is done...
# Record 628 is done...
# Record 629 is done...
# Record 630 is done...
# Record 631 is done...
# Record 632 is done...
# Record 633 is done...
# Record 634 is done...
# Record 635 is done...
# Record 636 is done...
# Record 637 is done...
# Record 638 is done...
# Record 639 is done...
# Record 640 is done...
# Record 641 is done...
# Record 642 is done...
# Record 643 is done...
# Record 644 is done...
# Record 645 is done...
# Record 646 is done...
# Record 647 is done...
# Record 648 is done...
# Record 649 is done...
# Record 650 is done...
# Record 651 is done...
# Record 652 is done...
# Record 653 is done...
# Record 654 is done...
# Record 655 is done...
# Record 656 is done...
# Record 657 is done...
# Record 658 is done...
# Record 659 is done...
# Record 660 is done...
# Record 661 is done...
# Record 662 is done...
# Record 663 is done...
# Record 664 is done...
# Record 665 is done...
# Record 666 is done...
# Record 667 is done...
# Record 668 is done...
# Record 669 is done...
# Record 670 is done...
# Record 671 is done...
# Record 672 is done...
# Record 673 is done...
# Record 674 is done...
# Record 675 is done...
# Record 676 is done...
# Record 677 is done...
# Record 678 is done...
# Record 679 is done...
# Record 680 is done...
# Record 681 is done...
# Record 682 is done...
# Record 683 is done...
# Record 684 is done...
# Record 685 is done...
# Record 686 is done...
# Record 687 is done...
# Record 688 is done...
# Record 689 is done...
# Record 690 is done...
# Record 691 is done...
# Record 692 is done...
# Record 693 is done...
# Record 694 is done...
# Record 695 is done...
# Record 696 is done...
# Record 697 is done...
# Record 698 is done...
# Record 699 is done...
# Record 700 is done...
# Record 701 is done...
# Record 702 is done...
# Record 703 is done...
# Record 704 is done...
# Record 705 is done...
# Record 706 is done...
# Record 707 is done...
# Record 708 is done...
# Record 709 is done...
# Record 710 is done...
# Record 711 is done...
# Record 712 is done...
# Record 713 is done...
# Record 714 is done...
# Record 715 is done...
# Record 716 is done...
# Record 717 is done...
# Record 718 is done...
# Record 719 is done...
# Record 720 is done...
# Record 721 is done...
# Record 722 is done...
# Record 723 is done...
# Record 724 is done...
# Record 725 is done...
# Record 726 is done...
# Record 727 is done...
# Record 728 is done...
# Record 729 is done...
# Record 730 is done...
# Record 731 is done...
# Record 732 is done...
# Record 733 is done...
# Record 734 is done...
# Record 735 is done...
# Record 736 is done...
# Record 737 is done...
# Record 738 is done...
# Record 739 is done...
# Record 740 is done...
# Record 741 is done...
# Record 742 is done...
# Record 743 is done...
# Record 744 is done...
# Record 745 is done...
# Record 746 is done...
# Record 747 is done...
# Record 748 is done...
# Record 749 is done...
# Record 750 is done...
# Record 751 is done...
# Record 752 is done...
# Record 753 is done...
# Record 754 is done...
# Record 755 is done...
# Record 756 is done...
# Record 757 is done...
# Record 758 is done...
# Record 759 is done...
# Record 760 is done...
# Record 761 is done...
# Record 762 is done...
# Record 763 is done...
# Record 764 is done...
# Record 765 is done...
# Record 766 is done...
# Record 767 is done...
# Record 768 is done...
# Record 769 is done...
# Record 770 is done...
# Record 771 is done...
# Record 772 is done...
# Record 773 is done...
# Record 774 is done...
# Record 775 is done...
# Record 776 is done...
# Record 777 is done...
# Record 778 is done...
# Record 779 is done...
# Record 780 is done...
# Record 781 is done...
# Record 782 is done...
# Record 783 is done...
# Record 784 is done...
# Record 785 is done...
# Record 786 is done...
# Record 787 is done...
# Record 788 is done...
# Record 789 is done...
# Record 790 is done...
# Record 791 is done...
# Record 792 is done...
# Record 793 is done...
# Record 794 is done...
# Record 795 is done...
# Record 796 is done...
# Record 797 is done...
# Record 798 is done...
# Record 799 is done...
# Record 800 is done...
# Record 801 is done...
# Record 802 is done...
# Record 803 is done...
# Record 804 is done...
# Record 805 is done...
# Record 806 is done...
# Record 807 is done...
# Record 808 is done...
# Record 809 is done...
# Record 810 is done...
# Record 811 is done...
# Record 812 is done...
# Record 813 is done...
# Record 814 is done...
# Record 815 is done...
# Record 816 is done...
# Record 817 is done...
# Record 818 is done...
# Record 819 is done...
# Record 820 is done...
# Record 821 is done...
# Record 822 is done...
# Record 823 is done...
# Record 824 is done...
# Record 825 is done...
# Record 826 is done...
# Record 827 is done...
# Record 828 is done...
# Record 829 is done...
# Record 830 is done...
# Record 831 is done...
# Record 832 is done...
# Record 833 is done...
# Record 834 is done...
# Record 835 is done...
# Record 836 is done...
# Record 837 is done...
# Record 838 is done...
# Record 839 is done...
# Record 840 is done...
# Record 841 is done...
# Record 842 is done...
# Record 843 is done...
# Record 844 is done...
# Record 845 is done...
# Record 846 is done...
# Record 847 is done...
# Record 848 is done...
# Record 849 is done...
# Record 850 is done...
# Record 851 is done...
# Record 852 is done...
# Record 853 is done...
# Record 854 is done...
# Record 855 is done...
# Record 856 is done...
# Record 857 is done...
# Record 858 is done...
# Record 859 is done...
# Record 860 is done...
# Record 861 is done...
# Record 862 is done...
# Record 863 is done...
# Record 864 is done...
# Record 865 is done...
# Record 866 is done...
# Record 867 is done...
# Record 868 is done...
# Record 869 is done...
# Record 870 is done...
# Record 871 is done...
# Record 872 is done...
# Record 873 is done...
# Record 874 is done...
# Record 875 is done...
# Record 876 is done...
# Record 877 is done...
# Record 878 is done...
# Record 879 is done...
# Record 880 is done...
# Record 881 is done...
# Record 882 is done...
# Record 883 is done...
# Record 884 is done...
# Record 885 is done...
# Record 886 is done...
# Record 887 is done...
# Record 888 is done...
# Record 889 is done...
# Record 890 is done...
# Record 891 is done...
# Record 892 is done...
# Record 893 is done...
# Record 894 is done...
# Record 895 is done...
# Record 896 is done...
# Record 897 is done...
# Record 898 is done...
# Record 899 is done...
# Record 900 is done...
# Record 901 is done...
# Record 902 is done...
# Record 903 is done...
# Record 904 is done...
# Record 905 is done...
# Record 906 is done...
# Record 907 is done...
# Record 908 is done...
# Record 909 is done...
# Record 910 is done...
# Record 911 is done...
# Record 912 is done...
# Record 913 is done...
# Record 914 is done...
# Record 915 is done...
# Record 916 is done...
# Record 917 is done...
# Record 918 is done...
# Record 919 is done...
# Record 920 is done...
# Record 921 is done...
# Record 922 is done...
# Record 923 is done...
# Record 924 is done...
# Record 925 is done...
# Record 926 is done...
# Record 927 is done...
# Record 928 is done...
# Record 929 is done...
# Record 930 is done...
# Record 931 is done...
# Record 932 is done...
# Record 933 is done...
# Record 934 is done...
# Record 935 is done...
# Record 936 is done...
# Record 937 is done...
# Record 938 is done...
# Record 939 is done...
# Record 940 is done...
# Record 941 is done...
# Record 942 is done...
# Record 943 is done...
# Record 944 is done...
# Record 945 is done...
# Record 946 is done...
# Record 947 is done...
# Record 948 is done...
# Record 949 is done...
# Record 950 is done...
# Record 951 is done...
# Record 952 is done...
# Record 953 is done...
# Record 954 is done...
# Record 955 is done...
# Record 956 is done...
# Record 957 is done...
# Record 958 is done...
# Record 959 is done...
# Record 960 is done...
# Record 961 is done...
# Record 962 is done...
# Record 963 is done...
# Record 964 is done...
# Record 965 is done...
# Record 966 is done...
# Record 967 is done...
# Record 968 is done...
# Record 969 is done...
# Record 970 is done...
# Record 971 is done...
# Record 972 is done...
# Record 973 is done...
# Record 974 is done...
# Record 975 is done...
# Record 976 is done...
# Record 977 is done...
# Record 978 is done...
# Record 979 is done...
# Record 980 is done...
# Record 981 is done...
# Record 982 is done...
# Record 983 is done...
# Record 984 is done...
# Record 985 is done...
# Record 986 is done...
# Record 987 is done...
# Record 988 is done...
# Record 989 is done...
# Record 990 is done...
# Record 991 is done...
# Record 992 is done...
# Record 993 is done...
# Record 994 is done...
# Record 995 is done...
# Record 996 is done...
# Record 997 is done...
# Record 998 is done...
# Record 999 is done...
# Record 1000 is done...
# Record 1001 is done...
# Record 1002 is done...
# Record 1003 is done...
# Record 1004 is done...
# Record 1005 is done...
# Record 1006 is done...
# Record 1007 is done...
# Record 1008 is done...
# Record 1009 is done...
# Record 1010 is done...
# Record 1011 is done...
# Record 1012 is done...
# Record 1013 is done...
# Record 1014 is done...
# Record 1015 is done...
# Record 1016 is done...
# Record 1017 is done...
# Record 1018 is done...
# Record 1019 is done...
# Record 1020 is done...
# Record 1021 is done...
# Record 1022 is done...
# Record 1023 is done...
# Record 1024 is done...
# Record 1025 is done...
# Record 1026 is done...
# Record 1027 is done...
# Record 1028 is done...
# Record 1029 is done...
# Record 1030 is done...
# Record 1031 is done...
# Record 1032 is done...
# Record 1033 is done...
# Record 1034 is done...
# Record 1035 is done...
# Record 1036 is done...
# Record 1037 is done...
# Record 1038 is done...
# Record 1039 is done...
# Record 1040 is done...
# Record 1041 is done...
# Record 1042 is done...
# Record 1043 is done...
# Record 1044 is done...
# Record 1045 is done...
# Record 1046 is done...
# Record 1047 is done...
# Record 1048 is done...
# Record 1049 is done...
# Record 1050 is done...
# Record 1051 is done...
# Record 1052 is done...
# Record 1053 is done...
# Record 1054 is done...
# Record 1055 is done...
# Record 1056 is done...
# Record 1057 is done...
# Record 1058 is done...
# Record 1059 is done...
# Record 1060 is done...
# Record 1061 is done...
# Record 1062 is done...
# Record 1063 is done...
# Record 1064 is done...
# Record 1065 is done...
# Record 1066 is done...
# Record 1067 is done...
# Record 1068 is done...
# Record 1069 is done...
# Record 1070 is done...
# Record 1071 is done...
# Record 1072 is done...
# Record 1073 is done...
# Record 1074 is done...
# Record 1075 is done...
# Record 1076 is done...
# Record 1077 is done...
# Record 1078 is done...
# Record 1079 is done...
# Record 1080 is done...
# Record 1081 is done...
# Record 1082 is done...
# Record 1083 is done...
# Record 1084 is done...
# Record 1085 is done...
# Record 1086 is done...
# Record 1087 is done...
# Record 1088 is done...
# Record 1089 is done...
# Record 1090 is done...
# Record 1091 is done...
# Record 1092 is done...
# Record 1093 is done...
# Record 1094 is done...
# Record 1095 is done...
# Record 1096 is done...
# Record 1097 is done...
# Record 1098 is done...
# Record 1099 is done...
# Record 1100 is done...
# Record 1101 is done...
# Record 1102 is done...
# Record 1103 is done...
# Record 1104 is done...
# Record 1105 is done...
# Record 1106 is done...
# Record 1107 is done...
# Record 1108 is done...
# Record 1109 is done...
# Record 1110 is done...
# Record 1111 is done...
# Record 1112 is done...
# Record 1113 is done...
# Record 1114 is done...
# Record 1115 is done...
# Record 1116 is done...
# Record 1117 is done...
# Record 1118 is done...
# Record 1119 is done...
# Record 1120 is done...
# Record 1121 is done...
# Record 1122 is done...
# Record 1123 is done...
# Record 1124 is done...
# Record 1125 is done...
# Record 1126 is done...
# Record 1127 is done...
# Record 1128 is done...
# Record 1129 is done...
# Record 1130 is done...
# Record 1131 is done...
# Record 1132 is done...
# Record 1133 is done...
# Record 1134 is done...
# Record 1135 is done...
# Record 1136 is done...
# Record 1137 is done...
# Record 1138 is done...
# Record 1139 is done...
# Record 1140 is done...
# Record 1141 is done...
# Record 1142 is done...
# Record 1143 is done...
# Record 1144 is done...
# Record 1145 is done...
# Record 1146 is done...
# Record 1147 is done...
# Record 1148 is done...
# Record 1149 is done...
# Record 1150 is done...
# Record 1151 is done...
# Record 1152 is done...
# Record 1153 is done...
# Record 1154 is done...
# Record 1155 is done...
# Record 1156 is done...
# Record 1157 is done...
# Record 1158 is done...
# Record 1159 is done...
# Record 1160 is done...
# Record 1161 is done...
# Record 1162 is done...
# Record 1163 is done...
# Record 1164 is done...
# Record 1165 is done...
# Record 1166 is done...
# Record 1167 is done...
# Record 1168 is done...
# Record 1169 is done...
# Record 1170 is done...
# Record 1171 is done...
# Record 1172 is done...
# Record 1173 is done...
# Record 1174 is done...
# Record 1175 is done...
# Record 1176 is done...
# Record 1177 is done...
# Record 1178 is done...
# Record 1179 is done...
# Record 1180 is done...
# Record 1181 is done...
# Record 1182 is done...
# Record 1183 is done...
# Record 1184 is done...
# Record 1185 is done...
# Record 1186 is done...
# Record 1187 is done...
# Record 1188 is done...
# Record 1189 is done...
# Record 1190 is done...
# Record 1191 is done...
# Record 1192 is done...
# Record 1193 is done...
# Record 1194 is done...
# Record 1195 is done...
# Record 1196 is done...
# Record 1197 is done...
# Record 1198 is done...
# Record 1199 is done...
# Record 1200 is done...
# Record 1201 is done...
# Record 1202 is done...
# Record 1203 is done...
# Record 1204 is done...
# Record 1205 is done...
# Record 1206 is done...
# Record 1207 is done...
# Record 1208 is done...
# Record 1209 is done...
# Record 1210 is done...
# Record 1211 is done...
# Record 1212 is done...
# Record 1213 is done...
# Record 1214 is done...
# Record 1215 is done...
# Record 1216 is done...
# Record 1217 is done...
# Record 1218 is done...
# Record 1219 is done...
# Record 1220 is done...
# Record 1221 is done...
# Record 1222 is done...
# Record 1223 is done...
# Record 1224 is done...
# Record 1225 is done...
# Record 1226 is done...
# Record 1227 is done...
# Record 1228 is done...
# Record 1229 is done...
# Record 1230 is done...
# Record 1231 is done...
# Record 1232 is done...
# Record 1233 is done...
# Record 1234 is done...
# Record 1235 is done...
# Record 1236 is done...
# Record 1237 is done...
# Record 1238 is done...
# Record 1239 is done...
# Record 1240 is done...
# Record 1241 is done...
# Record 1242 is done...
# Record 1243 is done...
# Record 1244 is done...
# Record 1245 is done...
# Record 1246 is done...
# Record 1247 is done...
# Record 1248 is done...
# Record 1249 is done...
# Record 1250 is done...
# Record 1251 is done...
# Record 1252 is done...
# Record 1253 is done...
# Record 1254 is done...
# Record 1255 is done...
# Record 1256 is done...
# Record 1257 is done...
# Record 1258 is done...
# Record 1259 is done...
# Record 1260 is done...
# Record 1261 is done...
# Record 1262 is done...
# Record 1263 is done...
# Record 1264 is done...
# Record 1265 is done...
# Record 1266 is done...
# Record 1267 is done...
# Record 1268 is done...
# Record 1269 is done...
# Record 1270 is done...
# Record 1271 is done...
# Record 1272 is done...
# Record 1273 is done...
# Record 1274 is done...
# Record 1275 is done...
# Record 1276 is done...
# Record 1277 is done...
# Record 1278 is done...
# Record 1279 is done...
# Record 1280 is done...
# Record 1281 is done...
# Record 1282 is done...
# Record 1283 is done...
# Record 1284 is done...
# Record 1285 is done...
# Record 1286 is done...
# Record 1287 is done...
# Record 1288 is done...
# Record 1289 is done...
# Record 1290 is done...
# Record 1291 is done...
# Record 1292 is done...
# Record 1293 is done...
# Record 1294 is done...
# Record 1295 is done...
# Record 1296 is done...
# Record 1297 is done...
# Record 1298 is done...
# Record 1299 is done...
# Record 1300 is done...
# Record 1301 is done...
# Record 1302 is done...
# Record 1303 is done...
# Record 1304 is done...
# Record 1305 is done...
# Record 1306 is done...
# Record 1307 is done...
# Record 1308 is done...
# Record 1309 is done...
# Record 1310 is done...
# Record 1311 is done...
# Record 1312 is done...
# Record 1313 is done...
# Record 1314 is done...
# Record 1315 is done...
# Record 1316 is done...
# Record 1317 is done...
# Record 1318 is done...
# Record 1319 is done...
# Record 1320 is done...
# Record 1321 is done...
# Record 1322 is done...
# Record 1323 is done...
# Record 1324 is done...
# Record 1325 is done...
# Record 1326 is done...
# Record 1327 is done...
# Record 1328 is done...
# Record 1329 is done...
# Record 1330 is done...
# Record 1331 is done...
# Record 1332 is done...
# Record 1333 is done...
# Record 1334 is done...
# Record 1335 is done...
# Record 1336 is done...
# Record 1337 is done...
# Record 1338 is done...
# Record 1339 is done...
# Record 1340 is done...
# Record 1341 is done...
# Record 1342 is done...
# Record 1343 is done...
# Record 1344 is done...
# Record 1345 is done...
# Record 1346 is done...
# Record 1347 is done...
# Record 1348 is done...
# Record 1349 is done...
# Record 1350 is done...
# Record 1351 is done...
# Record 1352 is done...
# Record 1353 is done...
# Record 1354 is done...
# Record 1355 is done...
# Record 1356 is done...
# Record 1357 is done...
# Record 1358 is done...
# Record 1359 is done...
# Record 1360 is done...
# Record 1361 is done...
# Record 1362 is done...
# Record 1363 is done...
# Record 1364 is done...
# Record 1365 is done...
# Record 1366 is done...
# Record 1367 is done...
# Record 1368 is done...
# Record 1369 is done...
# Record 1370 is done...
# Record 1371 is done...
# Record 1372 is done...
# Record 1373 is done...
# Record 1374 is done...
# Record 1375 is done...
# Record 1376 is done...
# Record 1377 is done...
# Record 1378 is done...
# Record 1379 is done...
# Record 1380 is done...
# Record 1381 is done...
# Record 1382 is done...
# Record 1383 is done...
# Record 1384 is done...
# Record 1385 is done...
# Record 1386 is done...
# Record 1387 is done...
# Record 1388 is done...
# Record 1389 is done...
# Record 1390 is done...
# Record 1391 is done...
# Record 1392 is done...
# Record 1393 is done...
# Record 1394 is done...
# Record 1395 is done...
# Record 1396 is done...
# Record 1397 is done...
# Record 1398 is done...
# Record 1399 is done...
# Record 1400 is done...
# Record 1401 is done...
# Record 1402 is done...
# Record 1403 is done...
# Record 1404 is done...
# Record 1405 is done...
# Record 1406 is done...
# Record 1407 is done...
# Record 1408 is done...
# Record 1409 is done...
# Record 1410 is done...
# Record 1411 is done...
# Record 1412 is done...
# Record 1413 is done...
# Record 1414 is done...
# Record 1415 is done...
# Record 1416 is done...
# Record 1417 is done...
# Record 1418 is done...
# Record 1419 is done...
# Record 1420 is done...
# Record 1421 is done...
# Record 1422 is done...
# Record 1423 is done...
# Record 1424 is done...
# Record 1425 is done...
# Record 1426 is done...
# Record 1427 is done...
# Record 1428 is done...
# Record 1429 is done...
# Record 1430 is done...
# Record 1431 is done...
# Record 1432 is done...
# Record 1433 is done...
# Record 1434 is done...
# Record 1435 is done...
# Record 1436 is done...
# Record 1437 is done...
# Record 1438 is done...
# Record 1439 is done...
# Record 1440 is done...
# Record 1441 is done...
# Record 1442 is done...
# Record 1443 is done...
# Record 1444 is done...
# Record 1445 is done...
# Record 1446 is done...
# Record 1447 is done...
# Record 1448 is done...
# Record 1449 is done...
# Record 1450 is done...
# Record 1451 is done...
# Record 1452 is done...
# Record 1453 is done...
# Record 1454 is done...
# Record 1455 is done...
# Record 1456 is done...
# Record 1457 is done...
# Record 1458 is done...
# Record 1459 is done...
# Record 1460 is done...
# Record 1461 is done...
# Record 1462 is done...
# Record 1463 is done...
# Record 1464 is done...
# Record 1465 is done...
# Record 1466 is done...
# Record 1467 is done...
# Record 1468 is done...
# Record 1469 is done...
# Record 1470 is done...
# Record 1471 is done...
# Record 1472 is done...
# Record 1473 is done...
# Record 1474 is done...
# Record 1475 is done...
# Record 1476 is done...
# Record 1477 is done...
# Record 1478 is done...
# Record 1479 is done...
# Record 1480 is done...
# Record 1481 is done...
# Record 1482 is done...
# Record 1483 is done...
# Record 1484 is done...
# Record 1485 is done...
# Record 1486 is done...
# Record 1487 is done...
# Record 1488 is done...
# Record 1489 is done...
# Record 1490 is done...
# Record 1491 is done...
# Record 1492 is done...
# Record 1493 is done...
# Record 1494 is done...
# Record 1495 is done...
# Record 1496 is done...
# Record 1497 is done...
# Record 1498 is done...
# Record 1499 is done...
# Record 1500 is done...
# Record 1501 is done...
# Record 1502 is done...
# Record 1503 is done...
# Record 1504 is done...
# Record 1505 is done...
# Record 1506 is done...
# Record 1507 is done...
# Record 1508 is done...
# Record 1509 is done...
# Record 1510 is done...
# Record 1511 is done...
# Record 1512 is done...
# Record 1513 is done...
# Record 1514 is done...
# Record 1515 is done...
# Record 1516 is done...
# Record 1517 is done...
# Record 1518 is done...
# Record 1519 is done...
# Record 1520 is done...
# Record 1521 is done...
# Record 1522 is done...
# Record 1523 is done...
# Record 1524 is done...
# Record 1525 is done...
# Record 1526 is done...
# Record 1527 is done...
# Record 1528 is done...
# Record 1529 is done...
# Record 1530 is done...
# Record 1531 is done...
# Record 1532 is done...
# Record 1533 is done...
# Record 1534 is done...
# Record 1535 is done...
# Record 1536 is done...
# Record 1537 is done...
# Record 1538 is done...
# Record 1539 is done...
# Record 1540 is done...
# Record 1541 is done...
# Record 1542 is done...
# Record 1543 is done...
# Record 1544 is done...
# Record 1545 is done...
# Record 1546 is done...
# Record 1547 is done...
# Record 1548 is done...
# Record 1549 is done...
# Record 1550 is done...
# Record 1551 is done...
# Record 1552 is done...
# Record 1553 is done...
# Record 1554 is done...
# Record 1555 is done...
# Record 1556 is done...
# Record 1557 is done...
# Record 1558 is done...
# Record 1559 is done...
# Record 1560 is done...
# Record 1561 is done...
# Record 1562 is done...
# Record 1563 is done...
# Record 1564 is done...
# Record 1565 is done...
# Record 1566 is done...
# Record 1567 is done...
# Record 1568 is done...
# Record 1569 is done...
# Record 1570 is done...
# Record 1571 is done...
# Record 1572 is done...
# Record 1573 is done...
# Record 1574 is done...
# Record 1575 is done...
# Record 1576 is done...
# Record 1577 is done...
# Record 1578 is done...
# Record 1579 is done...
# Record 1580 is done...
# Record 1581 is done...
# Record 1582 is done...
# Record 1583 is done...
# Record 1584 is done...
# Record 1585 is done...
# Record 1586 is done...
# Record 1587 is done...
# Record 1588 is done...
# Record 1589 is done...
# Record 1590 is done...
# Record 1591 is done...
# Record 1592 is done...
# Record 1593 is done...
# Record 1594 is done...
# Record 1595 is done...
# Record 1596 is done...
# Record 1597 is done...
# Record 1598 is done...
# Record 1599 is done...
# Record 1600 is done...
# Record 1601 is done...
# Record 1602 is done...
# Record 1603 is done...
# Record 1604 is done...
# Record 1605 is done...
# Record 1606 is done...
# Record 1607 is done...
# Record 1608 is done...
# Record 1609 is done...
# Record 1610 is done...
# Record 1611 is done...
# Record 1612 is done...
# Record 1613 is done...
# Record 1614 is done...
# Record 1615 is done...
# Record 1616 is done...
# Record 1617 is done...
# Record 1618 is done...
# Record 1619 is done...
# Record 1620 is done...
# Record 1621 is done...
# Record 1622 is done...
# Record 1623 is done...
# Record 1624 is done...
# Record 1625 is done...
# Record 1626 is done...
# Record 1627 is done...
# Record 1628 is done...
# Record 1629 is done...
# Record 1630 is done...
# Record 1631 is done...
# Record 1632 is done...
# Record 1633 is done...
# Record 1634 is done...
# Record 1635 is done...
# Record 1636 is done...
# Record 1637 is done...
# Record 1638 is done...
# Record 1639 is done...
# Record 1640 is done...
# Record 1641 is done...
# Record 1642 is done...
# Record 1643 is done...
# Record 1644 is done...
# Record 1645 is done...
# Record 1646 is done...
# Record 1647 is done...
# Record 1648 is done...
# Record 1649 is done...
# Record 1650 is done...
# Record 1651 is done...
# Record 1652 is done...
# Record 1653 is done...
# Record 1654 is done...
# Record 1655 is done...
# Record 1656 is done...
# Record 1657 is done...
# Record 1658 is done...
# Record 1659 is done...
# Record 1660 is done...
# Record 1661 is done...
# Record 1662 is done...
# Record 1663 is done...
# Record 1664 is done...
# Record 1665 is done...
# Record 1666 is done...
# Record 1667 is done...
# Record 1668 is done...
# Record 1669 is done...
# Record 1670 is done...
# Record 1671 is done...
# Record 1672 is done...
# Record 1673 is done...
# Record 1674 is done...
# Record 1675 is done...
# Record 1676 is done...
# Record 1677 is done...
# Record 1678 is done...
# Record 1679 is done...
# Record 1680 is done...
# Record 1681 is done...
# Record 1682 is done...
# Record 1683 is done...
# Record 1684 is done...
# Record 1685 is done...
# Record 1686 is done...
# Record 1687 is done...
# Record 1688 is done...
# Record 1689 is done...
# Record 1690 is done...
# Record 1691 is done...
# Record 1692 is done...
# Record 1693 is done...
# Record 1694 is done...
# Record 1695 is done...
# Record 1696 is done...
# Record 1697 is done...
# Record 1698 is done...
# Record 1699 is done...
# Record 1700 is done...
# Record 1701 is done...
# Record 1702 is done...
# Record 1703 is done...
# Record 1704 is done...
# Record 1705 is done...
# Record 1706 is done...
# Record 1707 is done...
# Record 1708 is done...
# Record 1709 is done...
# Record 1710 is done...
# Record 1711 is done...
# Record 1712 is done...
# Record 1713 is done...
# Record 1714 is done...
# Record 1715 is done...
# Record 1716 is done...
# Record 1717 is done...
# Record 1718 is done...
# Record 1719 is done...
# Record 1720 is done...
# Record 1721 is done...
# Record 1722 is done...
# Record 1723 is done...
# Record 1724 is done...
# Record 1725 is done...
# Record 1726 is done...
# Record 1727 is done...
# Record 1728 is done...
# Record 1729 is done...
# Record 1730 is done...
# Record 1731 is done...
# Record 1732 is done...
# Record 1733 is done...
# Record 1734 is done...
# Record 1735 is done...
# Record 1736 is done...
# Record 1737 is done...
# Record 1738 is done...
# Record 1739 is done...
# Record 1740 is done...
# Record 1741 is done...
# Record 1742 is done...
# Record 1743 is done...
# Record 1744 is done...
# Record 1745 is done...
# Record 1746 is done...
# Record 1747 is done...
# Record 1748 is done...
# Record 1749 is done...
# Record 1750 is done...
# Record 1751 is done...
# Record 1752 is done...
# Record 1753 is done...
# Record 1754 is done...
# Record 1755 is done...
# Record 1756 is done...
# Record 1757 is done...
# Record 1758 is done...
# Record 1759 is done...
# Record 1760 is done...
# Record 1761 is done...
# Record 1762 is done...
# Record 1763 is done...
# Record 1764 is done...
# Record 1765 is done...
# Record 1766 is done...
# Record 1767 is done...
# Record 1768 is done...
# Record 1769 is done...
# Record 1770 is done...
# Record 1771 is done...
# Record 1772 is done...
# Record 1773 is done...
# Record 1774 is done...
# Record 1775 is done...
# Record 1776 is done...
# Record 1777 is done...
# Record 1778 is done...
# Record 1779 is done...
# Record 1780 is done...
# Record 1781 is done...
# Record 1782 is done...
# Record 1783 is done...
# Record 1784 is done...
# Record 1785 is done...
# Record 1786 is done...
# Record 1787 is done...
# Record 1788 is done...
# Record 1789 is done...
# Record 1790 is done...
# Record 1791 is done...
# Record 1792 is done...
# Record 1793 is done...
# Record 1794 is done...
# Record 1795 is done...
# Record 1796 is done...
# Record 1797 is done...
# Record 1798 is done...
# Record 1799 is done...
# Record 1800 is done...
# Record 1801 is done...
# Record 1802 is done...
# Record 1803 is done...
# Record 1804 is done...
# Record 1805 is done...
# Record 1806 is done...
# Record 1807 is done...
# Record 1808 is done...
# Record 1809 is done...
# Record 1810 is done...
# Record 1811 is done...
# Record 1812 is done...
# Record 1813 is done...
# Record 1814 is done...
# Record 1815 is done...
# Record 1816 is done...
# Record 1817 is done...
# Record 1818 is done...
# Record 1819 is done...
# Record 1820 is done...
# Record 1821 is done...
# Record 1822 is done...
# Record 1823 is done...
# Record 1824 is done...
# Record 1825 is done...
# Record 1826 is done...
# Record 1827 is done...
# Record 1828 is done...
# Record 1829 is done...
# Record 1830 is done...
# Record 1831 is done...
# Record 1832 is done...
# Record 1833 is done...
# Record 1834 is done...
# Record 1835 is done...
# Record 1836 is done...
# Record 1837 is done...
# Record 1838 is done...
# Record 1839 is done...
# Record 1840 is done...
# Record 1841 is done...
# Record 1842 is done...
# Record 1843 is done...
# Record 1844 is done...
# Record 1845 is done...
# Record 1846 is done...
# Record 1847 is done...
# Record 1848 is done...
# Record 1849 is done...
# Record 1850 is done...
# Record 1851 is done...
# Record 1852 is done...
# Record 1853 is done...
# Record 1854 is done...
# Record 1855 is done...
# Record 1856 is done...
# Record 1857 is done...
# Record 1858 is done...
# Record 1859 is done...
# Record 1860 is done...
# Record 1861 is done...
# Record 1862 is done...
# Record 1863 is done...
# Record 1864 is done...
# Record 1865 is done...
# Record 1866 is done...
# Record 1867 is done...
# Record 1868 is done...
# Record 1869 is done...
# Record 1870 is done...
# Record 1871 is done...
# Record 1872 is done...
# Record 1873 is done...
# Record 1874 is done...
# Record 1875 is done...
# Record 1876 is done...
# Record 1877 is done...
# Record 1878 is done...
# Record 1879 is done...
# Record 1880 is done...
# Record 1881 is done...
# Record 1882 is done...
# Record 1883 is done...
# Record 1884 is done...
# Record 1885 is done...
# Record 1886 is done...
# Record 1887 is done...
# Record 1888 is done...
# Record 1889 is done...
# Record 1890 is done...
# Record 1891 is done...
# Record 1892 is done...
# Record 1893 is done...
# Record 1894 is done...
# Record 1895 is done...
# Record 1896 is done...
# Record 1897 is done...
# Record 1898 is done...
# Record 1899 is done...
# Record 1900 is done...
# Record 1901 is done...
# Record 1902 is done...
# Record 1903 is done...
# Record 1904 is done...
# Record 1905 is done...
# Record 1906 is done...
# Record 1907 is done...
# Record 1908 is done...
# Record 1909 is done...
# Record 1910 is done...
# Record 1911 is done...
# Record 1912 is done...
# Record 1913 is done...
# Record 1914 is done...
# Record 1915 is done...
# Record 1916 is done...
# Record 1917 is done...
# Record 1918 is done...
# Record 1919 is done...
# Record 1920 is done...
# Record 1921 is done...
# Record 1922 is done...
# Record 1923 is done...
# Record 1924 is done...
# Record 1925 is done...
# Record 1926 is done...
# Record 1927 is done...
# Record 1928 is done...
# Record 1929 is done...
# Record 1930 is done...
# Record 1931 is done...
# Record 1932 is done...
# Record 1933 is done...
# Record 1934 is done...
# Record 1935 is done...
# Record 1936 is done...
# Record 1937 is done...
# Record 1938 is done...
# Record 1939 is done...
# Record 1940 is done...
# Record 1941 is done...
# Record 1942 is done...
# Record 1943 is done...
# Record 1944 is done...
# Record 1945 is done...
# Record 1946 is done...
# Record 1947 is done...
# Record 1948 is done...
# Record 1949 is done...
# Record 1950 is done...
# Record 1951 is done...
# Record 1952 is done...
# Record 1953 is done...
# Record 1954 is done...
# Record 1955 is done...
# Record 1956 is done...
# Record 1957 is done...
# Record 1958 is done...
# Record 1959 is done...
# Record 1960 is done...
# Record 1961 is done...
# Record 1962 is done...
# Record 1963 is done...
# Record 1964 is done...
# Record 1965 is done...
# Record 1966 is done...
# Record 1967 is done...
# Record 1968 is done...
# Record 1969 is done...
# Record 1970 is done...
# Record 1971 is done...
# Record 1972 is done...
# Record 1973 is done...
# Record 1974 is done...
# Record 1975 is done...
# Record 1976 is done...
# Record 1977 is done...
# Record 1978 is done...
# Record 1979 is done...
# Record 1980 is done...
# Record 1981 is done...
# Record 1982 is done...
# Record 1983 is done...
# Record 1984 is done...
# Record 1985 is done...
# Record 1986 is done...
# Record 1987 is done...
# Record 1988 is done...
# Record 1989 is done...
# Record 1990 is done...
# Record 1991 is done...
# Record 1992 is done...
# Record 1993 is done...
# Record 1994 is done...
# Record 1995 is done...
# Record 1996 is done...
# Record 1997 is done...
# Record 1998 is done...
# Record 1999 is done...
# Record 2000 is done...
# Record 2001 is done...
# Record 2002 is done...
# Record 2003 is done...
# Record 2004 is done...
# Record 2005 is done...
# Record 2006 is done...
# Record 2007 is done...
# Record 2008 is done...
# Record 2009 is done...
# Record 2010 is done...
# Record 2011 is done...
# Record 2012 is done...
# Record 2013 is done...
# Record 2014 is done...
# Record 2015 is done...
# Record 2016 is done...
# Record 2017 is done...
# Record 2018 is done...
# Record 2019 is done...
# Record 2020 is done...
# Record 2021 is done...
# Record 2022 is done...
# Record 2023 is done...
# Record 2024 is done...
# Record 2025 is done...
# Record 2026 is done...
# Record 2027 is done...
# Record 2028 is done...
# Record 2029 is done...
# Record 2030 is done...
# Record 2031 is done...
# Record 2032 is done...
# Record 2033 is done...
# Record 2034 is done...
# Record 2035 is done...
# Record 2036 is done...
# Record 2037 is done...
# Record 2038 is done...
# Record 2039 is done...
# Record 2040 is done...
# Record 2041 is done...
# Record 2042 is done...
# Record 2043 is done...
# Record 2044 is done...
# Record 2045 is done...
# Record 2046 is done...
# Record 2047 is done...
# Record 2048 is done...
# Record 2049 is done...
# Record 2050 is done...
# Record 2051 is done...
# Record 2052 is done...
# Record 2053 is done...
# Record 2054 is done...
# Record 2055 is done...
# Record 2056 is done...
# Record 2057 is done...
# Record 2058 is done...
# Record 2059 is done...
# Record 2060 is done...
# Record 2061 is done...
# Record 2062 is done...
# Record 2063 is done...
# Record 2064 is done...
# Record 2065 is done...
# Record 2066 is done...
# Record 2067 is done...
# Record 2068 is done...
# Record 2069 is done...
# Record 2070 is done...
# Record 2071 is done...
# Record 2072 is done...
# Record 2073 is done...
# Record 2074 is done...
# Record 2075 is done...
# Record 2076 is done...
# Record 2077 is done...
# Record 2078 is done...
# Record 2079 is done...
# Record 2080 is done...
# Record 2081 is done...
# Record 2082 is done...
# Record 2083 is done...
# Record 2084 is done...
# Record 2085 is done...
# Record 2086 is done...
# Record 2087 is done...
# Record 2088 is done...
# Record 2089 is done...
# Record 2090 is done...
# Record 2091 is done...
# Record 2092 is done...
# Record 2093 is done...
# Record 2094 is done...
# Record 2095 is done...
# Record 2096 is done...
# Record 2097 is done...
# Record 2098 is done...
# Record 2099 is done...
# Record 2100 is done...
# Record 2101 is done...
# Record 2102 is done...
# Record 2103 is done...
# Record 2104 is done...
# Record 2105 is done...
# Record 2106 is done...
# Record 2107 is done...
# Record 2108 is done...
# Record 2109 is done...
# Record 2110 is done...
# Record 2111 is done...
# Record 2112 is done...
# Record 2113 is done...
# Record 2114 is done...
# Record 2115 is done...
# Record 2116 is done...
# Record 2117 is done...
# Record 2118 is done...
# Record 2119 is done...
# Record 2120 is done...
# Record 2121 is done...
# Record 2122 is done...
# Record 2123 is done...
# Record 2124 is done...
# Record 2125 is done...
# Record 2126 is done...
# Record 2127 is done...
# Record 2128 is done...
# Record 2129 is done...
# Record 2130 is done...
# Record 2131 is done...
# Record 2132 is done...
# Record 2133 is done...
# Record 2134 is done...
# Record 2135 is done...
# ...
# Record 9359 is done...
# Record 9360 is done...
# Record 9361 is done...
# Record 9362 is done...
# Record 9363 is done...
# Record 9364 is done...
# Record 9365 is done...
# Record 9366 is done...
# Record 9367 is done...
# Record 9368 is done...
# Record 9369 is done...
# Record 9370 is done...
# Record 9371 is done...
# Record 9372 is done...
# Record 9373 is done...
# Record 9374 is done...
# Record 9375 is done...
# Record 9376 is done...
# Record 9377 is done...
# Record 9378 is done...
# Record 9379 is done...
# Record 9380 is done...
# Record 9381 is done...
# Record 9382 is done...
# Record 9383 is done...
# Record 9384 is done...
# Record 9385 is done...
# Record 9386 is done...
# Record 9387 is done...
# Record 9388 is done...
# Record 9389 is done...
# Record 9390 is done...
# Record 9391 is done...
# Record 9392 is done...
# Record 9393 is done...
# Record 9394 is done...
# Record 9395 is done...
# Record 9396 is done...
# Record 9397 is done...
# Record 9398 is done...
# Record 9399 is done...
# Record 9400 is done...
# Record 9401 is done...
# Record 9402 is done...
# Record 9403 is done...
# Record 9404 is done...
# Record 9405 is done...
# Record 9406 is done...
# Record 9407 is done...
# Record 9408 is done...
# Record 9409 is done...
# Record 9410 is done...
# Record 9411 is done...
# Record 9412 is done...
# Record 9413 is done...
# Record 9414 is done...
# Record 9415 is done...
# Record 9416 is done...
# Record 9417 is done...
# Record 9418 is done...
# Record 9419 is done...
# Record 9420 is done...
# Record 9421 is done...
# Record 9422 is done...
# Record 9423 is done...
# Record 9424 is done...
# Record 9425 is done...
# Record 9426 is done...
# Record 9427 is done...
# Record 9428 is done...
# Record 9429 is done...
# Record 9430 is done...
# Record 9431 is done...
# Record 9432 is done...
# Record 9433 is done...
# Record 9434 is done...
# Record 9435 is done...
# Record 9436 is done...
# Record 9437 is done...
# Record 9438 is done...
# Record 9439 is done...
# Record 9440 is done...
# Record 9441 is done...
# Record 9442 is done...
# Record 9443 is done...
# Record 9444 is done...
# Record 9445 is done...
# Record 9446 is done...
# Record 9447 is done...
# Record 9448 is done...
# Record 9449 is done...
# Record 9450 is done...
# Record 9451 is done...
# Record 9452 is done...
# Record 9453 is done...
# Record 9454 is done...
# Record 9455 is done...
# Record 9456 is done...
# Record 9457 is done...
# Record 9458 is done...
# Record 9459 is done...
# Record 9460 is done...
# Record 9461 is done...
# Record 9462 is done...
# Record 9463 is done...
# Record 9464 is done...
# Record 9465 is done...
# Record 9466 is done...
# Record 9467 is done...
# Record 9468 is done...
# Record 9469 is done...
# Record 9470 is done...
# Record 9471 is done...
# Record 9472 is done...
# Record 9473 is done...
# Record 9474 is done...
# Record 9475 is done...
# Record 9476 is done...
# Record 9477 is done...
# Record 9478 is done...
# Record 9479 is done...
# Record 9480 is done...
# Record 9481 is done...
# Record 9482 is done...
# Record 9483 is done...
# Record 9484 is done...
# Record 9485 is done...
# Record 9486 is done...
# Record 9487 is done...
# Record 9488 is done...
# Record 9489 is done...
# Record 9490 is done...
# Record 9491 is done...
# Record 9492 is done...
# Record 9493 is done...
# Record 9494 is done...
# Record 9495 is done...
# Record 9496 is done...
# Record 9497 is done...
# Record 9498 is done...
# Record 9499 is done...
# Record 9500 is done...
# Record 9501 is done...
# Record 9502 is done...
# Record 9503 is done...
# Record 9504 is done...
# Record 9505 is done...
# Record 9506 is done...
# Record 9507 is done...
# Record 9508 is done...
# Record 9509 is done...
# Record 9510 is done...
# Record 9511 is done...
# Record 9512 is done...
# Record 9513 is done...
# Record 9514 is done...
# Record 9515 is done...
# Record 9516 is done...
# Record 9517 is done...
# Record 9518 is done...
# Record 9519 is done...
# Record 9520 is done...
# Record 9521 is done...
# Record 9522 is done...
# Record 9523 is done...
# Record 9524 is done...
# Record 9525 is done...
# Record 9526 is done...
# Record 9527 is done...
# Record 9528 is done...
# Record 9529 is done...
# Record 9530 is done...
# Record 9531 is done...
# Record 9532 is done...
# Record 9533 is done...
# Record 9534 is done...
# Record 9535 is done...
# Record 9536 is done...
# Record 9537 is done...
# Record 9538 is done...
# Record 9539 is done...
# Record 9540 is done...
# Record 9541 is done...
# Record 9542 is done...
# Record 9543 is done...
# Record 9544 is done...
# Record 9545 is done...
# Record 9546 is done...
# Record 9547 is done...
# Record 9548 is done...
# Record 9549 is done...
# Record 9550 is done...
# Record 9551 is done...
# Record 9552 is done...
# Record 9553 is done...
# Record 9554 is done...
# Record 9555 is done...
# Record 9556 is done...
# Record 9557 is done...
# Record 9558 is done...
# Record 9559 is done...
# Record 9560 is done...
# Record 9561 is done...
# Record 9562 is done...
# Record 9563 is done...
# Record 9564 is done...
# Record 9565 is done...
# Record 9566 is done...
# Record 9567 is done...
# Record 9568 is done...
# Record 9569 is done...
# Record 9570 is done...
# Record 9571 is done...
# Record 9572 is done...
# Record 9573 is done...
# Record 9574 is done...
# Record 9575 is done...
# Record 9576 is done...
# Record 9577 is done...
# Record 9578 is done...
# Record 9579 is done...
# Record 9580 is done...
# Record 9581 is done...
# Record 9582 is done...
# Record 9583 is done...
# Record 9584 is done...
# Record 9585 is done...
# Record 9586 is done...
# Record 9587 is done...
# Record 9588 is done...
# Record 9589 is done...
# Record 9590 is done...
# Record 9591 is done...
# Record 9592 is done...
# Record 9593 is done...
# Record 9594 is done...
# Record 9595 is done...
# Record 9596 is done...
# Record 9597 is done...
# Record 9598 is done...
# Record 9599 is done...
# Record 9600 is done...
# Record 9601 is done...
# Record 9602 is done...
# Record 9603 is done...
# Record 9604 is done...
# Record 9605 is done...
# Record 9606 is done...
# Record 9607 is done...
# Record 9608 is done...
# Record 9609 is done...
# Record 9610 is done...
# Record 9611 is done...
# Record 9612 is done...
# Record 9613 is done...
# Record 9614 is done...
# Record 9615 is done...
# Record 9616 is done...
# Record 9617 is done...
# Record 9618 is done...
# Record 9619 is done...
# Record 9620 is done...
# Record 9621 is done...
# Record 9622 is done...
# Record 9623 is done...
# Record 9624 is done...
# Record 9625 is done...
# Record 9626 is done...
# Record 9627 is done...
# Record 9628 is done...
# Record 9629 is done...
# Record 9630 is done...
# Record 9631 is done...
# Record 9632 is done...
# Record 9633 is done...
# Record 9634 is done...
# Record 9635 is done...
# Record 9636 is done...
# Record 9637 is done...
# Record 9638 is done...
# Record 9639 is done...
# Record 9640 is done...
# Record 9641 is done...
# Record 9642 is done...
# Record 9643 is done...
# Record 9644 is done...
# Record 9645 is done...
# Record 9646 is done...
# Record 9647 is done...
# Record 9648 is done...
# Record 9649 is done...
# Record 9650 is done...
# Record 9651 is done...
# Record 9652 is done...
# Record 9653 is done...
# Record 9654 is done...
# Record 9655 is done...
# Record 9656 is done...
# Record 9657 is done...
# Record 9658 is done...
# Record 9659 is done...
# Record 9660 is done...
# Record 9661 is done...
# Record 9662 is done...
# Record 9663 is done...
# Record 9664 is done...
# Record 9665 is done...
# Record 9666 is done...
# Record 9667 is done...
# Record 9668 is done...
# Record 9669 is done...
# Record 9670 is done...
# Record 9671 is done...
# Record 9672 is done...
# Record 9673 is done...
# Record 9674 is done...
# Record 9675 is done...
# Record 9676 is done...
# Record 9677 is done...
# Record 9678 is done...
# Record 9679 is done...
# Record 9680 is done...
# Record 9681 is done...
# Record 9682 is done...
# Record 9683 is done...
# Record 9684 is done...
# Record 9685 is done...
# Record 9686 is done...
# Record 9687 is done...
# Record 9688 is done...
# Record 9689 is done...
# Record 9690 is done...
# Record 9691 is done...
# Record 9692 is done...
# Record 9693 is done...
# Record 9694 is done...
# Record 9695 is done...
# Record 9696 is done...
# Record 9697 is done...
# Record 9698 is done...
# Record 9699 is done...
# Record 9700 is done...
# Record 9701 is done...
# Record 9702 is done...
# Record 9703 is done...
# Record 9704 is done...
# Record 9705 is done...
# Record 9706 is done...
# Record 9707 is done...
# Record 9708 is done...
# Record 9709 is done...
# Record 9710 is done...
# Record 9711 is done...
# Record 9712 is done...
# Record 9713 is done...
# Record 9714 is done...
# Record 9715 is done...
# Record 9716 is done...
# Record 9717 is done...
# Record 9718 is done...
# Record 9719 is done...
# Record 9720 is done...
# Record 9721 is done...
# Record 9722 is done...
# Record 9723 is done...
# Record 9724 is done...
# Record 9725 is done...
# Record 9726 is done...
# Record 9727 is done...
# Record 9728 is done...
# Record 9729 is done...
# Record 9730 is done...
# Record 9731 is done...
# Record 9732 is done...
# Record 9733 is done...
# Record 9734 is done...
# Record 9735 is done...
# Record 9736 is done...
# Record 9737 is done...
# Record 9738 is done...
# Record 9739 is done...
# Record 9740 is done...
# Record 9741 is done...
# Record 9742 is done...
# Record 9743 is done...
# Record 9744 is done...
# Record 9745 is done...
# Record 9746 is done...
# Record 9747 is done...
# Record 9748 is done...
# Record 9749 is done...
# Record 9750 is done...
# Record 9751 is done...
# Record 9752 is done...
# Record 9753 is done...
# Record 9754 is done...
# Record 9755 is done...
# Record 9756 is done...
# Record 9757 is done...
# Record 9758 is done...
# Record 9759 is done...
# Record 9760 is done...
# Record 9761 is done...
# Record 9762 is done...
# Record 9763 is done...
# Record 9764 is done...
# Record 9765 is done...
# Record 9766 is done...
# Record 9767 is done...
# Record 9768 is done...
# Record 9769 is done...
# Record 9770 is done...
# Record 9771 is done...
# Record 9772 is done...
# Record 9773 is done...
# Record 9774 is done...
# Record 9775 is done...
# Record 9776 is done...
# Record 9777 is done...
# Record 9778 is done...
# Record 9779 is done...
# Record 9780 is done...
# Record 9781 is done...
# Record 9782 is done...
# Record 9783 is done...
# Record 9784 is done...
# Record 9785 is done...
# Record 9786 is done...
# Record 9787 is done...
# Record 9788 is done...
# Record 9789 is done...
# Record 9790 is done...
# Record 9791 is done...
# Record 9792 is done...
# Record 9793 is done...
# Record 9794 is done...
# Record 9795 is done...
# Record 9796 is done...
# Record 9797 is done...
# Record 9798 is done...
# Record 9799 is done...
# Record 9800 is done...
# Record 9801 is done...
# Record 9802 is done...
# Record 9803 is done...
# Record 9804 is done...
# Record 9805 is done...
# Record 9806 is done...
# Record 9807 is done...
# Record 9808 is done...
# Record 9809 is done...
# Record 9810 is done...
# Record 9811 is done...
# Record 9812 is done...
# Record 9813 is done...
# Record 9814 is done...
# Record 9815 is done...
# Record 9816 is done...
# Record 9817 is done...
# Record 9818 is done...
# Record 9819 is done...
# Record 9820 is done...
# Record 9821 is done...
# Record 9822 is done...
# Record 9823 is done...
# Record 9824 is done...
# Record 9825 is done...
# Record 9826 is done...
# Record 9827 is done...
# Record 9828 is done...
# Record 9829 is done...
# Record 9830 is done...
# Record 9831 is done...
# Record 9832 is done...
# Record 9833 is done...
# Record 9834 is done...
# Record 9835 is done...
# Record 9836 is done...
# Record 9837 is done...
# Record 9838 is done...
# Record 9839 is done...
# Record 9840 is done...
# Record 9841 is done...
# Record 9842 is done...
# Record 9843 is done...
# Record 9844 is done...
# Record 9845 is done...
# Record 9846 is done...
# Record 9847 is done...
# Record 9848 is done...
# Record 9849 is done...
# Record 9850 is done...
# Record 9851 is done...
# Record 9852 is done...
# Record 9853 is done...
# Record 9854 is done...
# Record 9855 is done...
# Record 9856 is done...
# Record 9857 is done...
# Record 9858 is done...
# Record 9859 is done...
# Record 9860 is done...
# Record 9861 is done...
# Record 9862 is done...
# Record 9863 is done...
# Record 9864 is done...
# Record 9865 is done...
# Record 9866 is done...
# Record 9867 is done...
# Record 9868 is done...
# Record 9869 is done...
# Record 9870 is done...
# Record 9871 is done...
# Record 9872 is done...
# Record 9873 is done...
# Record 9874 is done...
# Record 9875 is done...
# Record 9876 is done...
# Record 9877 is done...
# Record 9878 is done...
# Record 9879 is done...
# Record 9880 is done...
# Record 9881 is done...
# Record 9882 is done...
# Record 9883 is done...
# Record 9884 is done...
# Record 9885 is done...
# Record 9886 is done...
# Record 9887 is done...
# Record 9888 is done...
# Record 9889 is done...
# Record 9890 is done...
# Record 9891 is done...
# Record 9892 is done...
# Record 9893 is done...
# Record 9894 is done...
# Record 9895 is done...
# Record 9896 is done...
# Record 9897 is done...
# Record 9898 is done...
# Record 9899 is done...
# Record 9900 is done...
# Record 9901 is done...
# Record 9902 is done...
# Record 9903 is done...
# Record 9904 is done...
# Record 9905 is done...
# Record 9906 is done...
# Record 9907 is done...
# Record 9908 is done...
# Record 9909 is done...
# Record 9910 is done...
# Record 9911 is done...
# Record 9912 is done...
# Record 9913 is done...
# Record 9914 is done...
# Record 9915 is done...
# Record 9916 is done...
# Record 9917 is done...
# Record 9918 is done...
# Record 9919 is done...
# Record 9920 is done...
# Record 9921 is done...
# Record 9922 is done...
# Record 9923 is done...
# Record 9924 is done...
# Record 9925 is done...
# Record 9926 is done...
# Record 9927 is done...
# Record 9928 is done...
# Record 9929 is done...
# Record 9930 is done...
# Record 9931 is done...
# Record 9932 is done...
# Record 9933 is done...
# Record 9934 is done...
# Record 9935 is done...
# Record 9936 is done...
# Record 9937 is done...
# Record 9938 is done...
# Record 9939 is done...
# Record 9940 is done...
# Record 9941 is done...
# Record 9942 is done...
# Record 9943 is done...
# Record 9944 is done...
# Record 9945 is done...
# Record 9946 is done...
# Record 9947 is done...
# Record 9948 is done...
# Record 9949 is done...
# Record 9950 is done...
# Record 9951 is done...
# Record 9952 is done...
# Record 9953 is done...
# Record 9954 is done...
# Record 9955 is done...
# Record 9956 is done...
# Record 9957 is done...
# Record 9958 is done...
# Record 9959 is done...
# Record 9960 is done...
# Record 9961 is done...
# Record 9962 is done...
# Record 9963 is done...
# Record 9964 is done...
# Record 9965 is done...
# Record 9966 is done...
# Record 9967 is done...
# Record 9968 is done...
# Record 9969 is done...
# Record 9970 is done...
# Record 9971 is done...
# Record 9972 is done...
# Record 9973 is done...
# Record 9974 is done...
# Record 9975 is done...
# Record 9976 is done...
# Record 9977 is done...
# Record 9978 is done...
# Record 9979 is done...
# Record 9980 is done...
# Record 9981 is done...
# Record 9982 is done...
# Record 9983 is done...
# Record 9984 is done...
# Record 9985 is done...
# Record 9986 is done...
# Record 9987 is done...
# Record 9988 is done...
# Record 9989 is done...
# Record 9990 is done...
# Record 9991 is done...
# Record 9992 is done...
# Record 9993 is done...
# Record 9994 is done...
# Record 9995 is done...
# Record 9996 is done...
# Record 9997 is done...
# Record 9998 is done...
# Record 9999 is done...
# Record 10000 is done...
# Record 10001 is done...
# Record 10002 is done...
# Record 10003 is done...
# Record 10004 is done...
# Record 10005 is done...
# Record 10006 is done...
# Record 10007 is done...
# Record 10008 is done...
# Record 10009 is done...
# Record 10010 is done...
# Record 10011 is done...
# Record 10012 is done...
# Record 10013 is done...
# Record 10014 is done...
# Record 10015 is done...
# Record 10016 is done...
# Record 10017 is done...
# Record 10018 is done...
# Record 10019 is done...
# Record 10020 is done...
# Record 10021 is done...
# Record 10022 is done...
# Record 10023 is done...
# Record 10024 is done...
# Record 10025 is done...
# Record 10026 is done...
# Record 10027 is done...
# Record 10028 is done...
# Record 10029 is done...
# Record 10030 is done...
# Record 10031 is done...
# Record 10032 is done...
# Record 10033 is done...
# Record 10034 is done...
# Record 10035 is done...
# Record 10036 is done...
# Record 10037 is done...
# Record 10038 is done...
# Record 10039 is done...
# Record 10040 is done...
# Record 10041 is done...
# Record 10042 is done...
# Record 10043 is done...
# Record 10044 is done...
# Record 10045 is done...
# Record 10046 is done...
# Record 10047 is done...
# Record 10048 is done...
# Record 10049 is done...
# Record 10050 is done...
# Get dataset done !
